# %%
# importing the tf guys
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import plot_model

# tool for manipulate the data
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
X, y = load_iris(as_frame=True, return_X_y=True)

# %%
X.sample(5)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 148                6.2               3.4                5.4               2.3
# 114                5.8               2.8                5.1               2.4
# 69                 5.6               2.5                3.9               1.1
# 117                7.7               3.8                6.7               2.2
# 139                6.9               3.1                5.4               2.1

# %%
y.sample(5)
# Out:
# 80    1
# 67    1
# 10    0
# 46    0
# 9     0
# Name: target, dtype: int64

# %%
# splitting the data

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = Sequential([
    Dense(
        units=100,
        input_shape=(X_train.shape[1],),
        activation="relu",
        kernel_initializer='uniform',
    ),
    Dropout(0.25),
    Dense(
        units=4,
        activation="relu",
        kernel_initializer='uniform',
    ),
    Dense(
        units=3,
        activation="softmax",
        kernel_initializer='uniform',
    )
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 100)               500
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_5 (Dense)             (None, 4)                 404
#
#  dense_6 (Dense)             (None, 3)                 15
#
# =================================================================
# Total params: 919 (3.59 KB)
# Trainable params: 919 (3.59 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
plot_model(model)

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
model.fit(
    X_train,
    y_train,
    epochs=100,
    verbose=True,
)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 8ms/step - loss: 1.0984 - accuracy: 0.4083
# Epoch 2/100
# 4/4 [==============================] - 0s 8ms/step - loss: 1.0981 - accuracy: 0.5417
# Epoch 3/100
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0971 - accuracy: 0.6000
# Epoch 4/100
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0962 - accuracy: 0.4750
# Epoch 5/100
# 4/4 [==============================] - 0s 8ms/step - loss: 1.0947 - accuracy: 0.3583
# Epoch 6/100
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0925 - accuracy: 0.3333
# Epoch 7/100
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0899 - accuracy: 0.3167
# Epoch 8/100
# 4/4 [==============================] - 0s 8ms/step - loss: 1.0865 - accuracy: 0.3167
# Epoch 9/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0811 - accuracy: 0.3250
# Epoch 10/100
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0760 - accuracy: 0.3167
# Epoch 11/100
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0689 - accuracy: 0.3167
# Epoch 12/100
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0603 - accuracy: 0.3167
# Epoch 13/100
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0471 - accuracy: 0.3250
# Epoch 14/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0321 - accuracy: 0.3500
# Epoch 15/100
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0173 - accuracy: 0.4167
# Epoch 16/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0003 - accuracy: 0.4500
# Epoch 17/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9804 - accuracy: 0.4750
# Epoch 18/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9572 - accuracy: 0.5667
# Epoch 19/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.9451 - accuracy: 0.5333
# Epoch 20/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9207 - accuracy: 0.5750
# Epoch 21/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9029 - accuracy: 0.5667
# Epoch 22/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8856 - accuracy: 0.5917
# Epoch 23/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8751 - accuracy: 0.6250
# Epoch 24/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8615 - accuracy: 0.6417
# Epoch 25/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8516 - accuracy: 0.6417
# Epoch 26/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8449 - accuracy: 0.6167
# Epoch 27/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8310 - accuracy: 0.6417
# Epoch 28/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8285 - accuracy: 0.6583
# Epoch 29/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.8195 - accuracy: 0.6583
# Epoch 30/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8123 - accuracy: 0.6583
# Epoch 31/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8099 - accuracy: 0.6500
# Epoch 32/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8020 - accuracy: 0.6500
# Epoch 33/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8002 - accuracy: 0.6500
# Epoch 34/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7911 - accuracy: 0.6583
# Epoch 35/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.